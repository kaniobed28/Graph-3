# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
headers = ["UT","LT","h'F","foF2","hpF2","SF","ES"]

# %%
data_2003G02F = pd.read_csv(r"C:\Users\kanio\Desktop\newGraphs\2003 07\2003G02F.PAL", delim_whitespace=True, skiprows=13,names=headers)
data_2003G03F = pd.read_csv(r"C:\Users\kanio\Desktop\newGraphs\2003 07\2003G03F.PAL", delim_whitespace=True, skiprows=13,names=headers)
data_2003G04F = pd.read_csv(r"C:\Users\kanio\Desktop\newGraphs\2003 07\2003G04F.PAL", delim_whitespace=True, skiprows=13,names=headers)
data_2003G05F = pd.read_csv(r"C:\Users\kanio\Desktop\newGraphs\2003 07\2003G05F.PAL", delim_whitespace=True, skiprows=13,names=headers)
data_2003G06F = pd.read_csv(r"C:\Users\kanio\Desktop\newGraphs\2003 07\2003G06F.PAL", delim_whitespace=True, skiprows=13,names=headers)
data_2003G07F = pd.read_csv(r"C:\Users\kanio\Desktop\newGraphs\2003 07\2003G07F.PAL", delim_whitespace=True, skiprows=13,names=headers)
data_2003G08F = pd.read_csv(r"C:\Users\kanio\Desktop\newGraphs\2003 07\2003G08F.PAL", delim_whitespace=True, skiprows=13,names=headers)

# %%
data_2003G02F
# Out:
#           UT       LT  h'F  foF2  hpF2 SF ES
# 0     0.9232  21.9232  224   5.4   283  Y  N
# 1     1.0033  22.0033  219   5.4   283  N  N
# 2     1.0832  22.0832  221   5.4   276  N  N
# 3     1.1732  22.1732  224   5.4   290  Y  N
# 4     1.2532  22.2532  221   5.2   269  N  N
# ..       ...      ...  ...   ...   ... .. ..
# 249  23.5832  20.5832  262   5.3   359  N  Y
# 250  23.6732  20.6732  259   4.2   314  N  Y
# 251  23.7532  20.7532  264   4.3   307  N  Y
# 252  23.8332  20.8332  264   5.3   364  N  Y
# 253  23.9232  20.9232  276   5.6   373  N  Y
#
# [254 rows x 7 columns]

# %%
# data_2003G02F = data_2003G02F.apply(pd.to_numeric,errors = 'coerce').fillna(0)
# data_2003G03F = data_2003G03F.apply(pd.to_numeric,errors = 'coerce').fillna(0)
# data_2003G04F = data_2003G04F.apply(pd.to_numeric,errors = 'coerce').fillna(0)
# data_2003G05F = data_2003G05F.apply(pd.to_numeric,errors = 'coerce').fillna(0)
# data_2003G06F = data_2003G06F.apply(pd.to_numeric,errors = 'coerce').fillna(0)
# data_2003G07F = data_2003G07F.apply(pd.to_numeric,errors = 'coerce').fillna(0)
# data_2003G08F = data_2003G08F.apply(pd.to_numeric,errors = 'coerce').fillna(0)

# %%
# print(data_2003G02F["hpF2"].unique())
# data_2003G02F["hpF2"].replace('-',data_2003G02F["h'F"].mean())

# %%
# print(data_2003G02F["h'F"].unique())
# data_2003G02F["h'F"].replace(0,data_2003G02F["h'F"].mean())

# %%
# print(data_2003G02F["foF2"].unique())
# data_2003G02F["foF2"].replace(0,data_2003G02F["h'F"].mean())

# %%
fig, ax = plt.subplots(3,1,figsize = (20,25))
ax[0].plot(data_2003G02F['LT'],data_2003G02F['foF2'],label ="2003G02F['foF2']" )
ax[0].plot(data_2003G03F['LT'],data_2003G03F['foF2'],label ="2003G03F['foF2']" )
ax[0].plot(data_2003G04F['LT'],data_2003G04F['foF2'],label ="2003G04F['foF2']" )
ax[0].plot(data_2003G05F['LT'],data_2003G05F['foF2'],label ="2003G05F['foF2']" )
ax[0].plot(data_2003G06F['LT'],data_2003G06F['foF2'],label ="2003G06F['foF2']" )
ax[0].plot(data_2003G07F['LT'],data_2003G07F['foF2'],label ="2003G07F['foF2']" )
ax[0].plot(data_2003G08F['LT'],data_2003G08F['foF2'],label ="2003G08F['foF2']" )

ax[0].legend(loc = 1)
# ax[0].tick_params(labelleft = False)

ax[1].plot(data_2003G02F['LT'],data_2003G02F["h'F"],label ='2003G02F["h`f"]')
ax[1].plot(data_2003G03F['LT'],data_2003G03F["h'F"],label ='2003G03F["h`f"]')
ax[1].plot(data_2003G04F['LT'],data_2003G04F["h'F"],label ='2003G04F["h`f"]')
ax[1].plot(data_2003G05F['LT'],data_2003G05F["h'F"],label ='2003G05F["h`f"]')
ax[1].plot(data_2003G06F['LT'],data_2003G06F["h'F"],label ='2003G06F["h`f"]')
ax[1].plot(data_2003G07F['LT'],data_2003G07F["h'F"],label ='2003G07F["h`f"]')
ax[1].plot(data_2003G08F['LT'],data_2003G08F["h'F"],label ='2003G08F["h`f"]')

ax[1].legend(loc = 1)
# ax[1].tick_params(labelleft = False)

ax[2].plot(data_2003G02F['LT'],data_2003G02F[['hpF2']])
ax[2].plot(data_2003G03F['LT'],data_2003G03F['hpF2'])
ax[2].plot(data_2003G04F['LT'],data_2003G04F['hpF2'])
ax[2].plot(data_2003G05F['LT'],data_2003G05F['hpF2'])
ax[2].plot(data_2003G06F['LT'],data_2003G06F['hpF2'])
ax[2].plot(data_2003G07F['LT'],data_2003G07F['hpF2'])
ax[2].plot(data_2003G08F['LT'],data_2003G08F['hpF2'])

# ax[2].tick_params(labelleft = False)

# %%
data_2003L02F_12 = pd.read_csv(r"C:\Users\kanio\Desktop\newGraphs\2003 12\2003L02F.PAL", delim_whitespace=True, skiprows=13,names=headers)
data_2003L03F_12 = pd.read_csv(r"C:\Users\kanio\Desktop\newGraphs\2003 12\2003L03F.PAL", delim_whitespace=True, skiprows=13,names=headers)
data_2003L04F_12 = pd.read_csv(r"C:\Users\kanio\Desktop\newGraphs\2003 12\2003L04F.PAL", delim_whitespace=True, skiprows=13,names=headers)
data_2003L05F_12 = pd.read_csv(r"C:\Users\kanio\Desktop\newGraphs\2003 12\2003L05F.PAL", delim_whitespace=True, skiprows=13,names=headers)
data_2003L06F_12 = pd.read_csv(r"C:\Users\kanio\Desktop\newGraphs\2003 12\2003L06F.PAL", delim_whitespace=True, skiprows=13,names=headers)
data_2003L07F_12 = pd.read_csv(r"C:\Users\kanio\Desktop\newGraphs\2003 12\2003L07F.PAL", delim_whitespace=True, skiprows=13,names=headers)
data_2003L08F_12 = pd.read_csv(r"C:\Users\kanio\Desktop\newGraphs\2003 12\2003L08F.PAL", delim_whitespace=True, skiprows=13,names=headers)

# %%
# data_2003L02F_12 = data_2003L02F_12.apply(pd.to_numeric,errors = 'coerce').fillna(0)
# data_2003L03F_12 = data_2003L03F_12.apply(pd.to_numeric,errors = 'coerce').fillna(0)
# data_2003L04F_12 = data_2003L04F_12.apply(pd.to_numeric,errors = 'coerce').fillna(0)
# data_2003L05F_12 = data_2003L05F_12.apply(pd.to_numeric,errors = 'coerce').fillna(0)
# data_2003L06F_12 = data_2003L06F_12.apply(pd.to_numeric,errors = 'coerce').fillna(0)
# data_2003L07F_12 = data_2003L07F_12.apply(pd.to_numeric,errors = 'coerce').fillna(0)
# data_2003L08F_12 = data_2003L08F_12.apply(pd.to_numeric,errors = 'coerce').fillna(0)

# %%
fig, ax = plt.subplots(3,1,figsize = (20,25))
ax[0].plot(data_2003L02F_12['LT'],data_2003L02F_12['foF2'],label ="2003L02F_12['foF2']" )
ax[0].plot(data_2003L03F_12['LT'],data_2003L03F_12['foF2'],label ="2003L03F_12['foF2']" )
ax[0].plot(data_2003L04F_12['LT'],data_2003L04F_12['foF2'],label ="2003L04F_12['foF2']" )
ax[0].plot(data_2003L05F_12['LT'],data_2003L05F_12['foF2'],label ="2003L05F_12['foF2']" )
ax[0].plot(data_2003L06F_12['LT'],data_2003L06F_12['foF2'],label ="2003L06F_12['foF2']" )
ax[0].plot(data_2003L07F_12['LT'],data_2003L07F_12['foF2'],label ="2003L07F_12['foF2']" )
ax[0].plot(data_2003L08F_12['LT'],data_2003L08F_12['foF2'],label ="2003L08F_12['foF2']" )

ax[0].legend(loc = 1)
# ax[0].tick_params(labelleft = False)

ax[1].plot(data_2003L02F_12['LT'],data_2003L02F_12["h'F"],label ='2003L02F_12["h`f"]')
ax[1].plot(data_2003L03F_12['LT'],data_2003L03F_12["h'F"],label ='2003L03F_12["h`f"]')
ax[1].plot(data_2003L04F_12['LT'],data_2003L04F_12["h'F"],label ='2003L04F_12["h`f"]')
ax[1].plot(data_2003L05F_12['LT'],data_2003L05F_12["h'F"],label ='2003L05F_12["h`f"]')
ax[1].plot(data_2003L06F_12['LT'],data_2003L06F_12["h'F"],label ='2003L06F_12["h`f"]')
ax[1].plot(data_2003L07F_12['LT'],data_2003L07F_12["h'F"],label ='2003L07F_12["h`f"]')
ax[1].plot(data_2003L08F_12['LT'],data_2003L08F_12["h'F"],label ='2003L08F_12["h`f"]')

ax[1].legend(loc = 1)
# ax[1].tick_params(labelleft = False)

ax[2].plot(data_2003L02F_12['LT'],data_2003L02F_12['hpF2'])
ax[2].plot(data_2003L03F_12['LT'],data_2003L03F_12['hpF2'])
ax[2].plot(data_2003L04F_12['LT'],data_2003L04F_12['hpF2'])
ax[2].plot(data_2003L05F_12['LT'],data_2003L05F_12['hpF2'])
ax[2].plot(data_2003L06F_12['LT'],data_2003L06F_12['hpF2'])
ax[2].plot(data_2003L07F_12['LT'],data_2003L07F_12['hpF2'])
ax[2].plot(data_2003L08F_12['LT'],data_2003L08F_12['hpF2'])

# ax[2].tick_params(labelleft = False)

# %%
data_2006F10F_06 = pd.read_csv(r"C:\Users\kanio\Desktop\newGraphs\2006 06\2006F10F.PAL", delim_whitespace=True, skiprows=13,names=headers)
data_2006F11F_06 = pd.read_csv(r"C:\Users\kanio\Desktop\newGraphs\2006 06\2006F11F.PAL", delim_whitespace=True, skiprows=13,names=headers)
data_2006F12F_06 = pd.read_csv(r"C:\Users\kanio\Desktop\newGraphs\2006 06\2006F12F.PAL", delim_whitespace=True, skiprows=13,names=headers)
data_2006F13F_06 = pd.read_csv(r"C:\Users\kanio\Desktop\newGraphs\2006 06\2006F13F.PAL", delim_whitespace=True, skiprows=13,names=headers)
data_2006F14F_06 = pd.read_csv(r"C:\Users\kanio\Desktop\newGraphs\2006 06\2006F14F.PAL", delim_whitespace=True, skiprows=13,names=headers)
data_2006F15F_06 = pd.read_csv(r"C:\Users\kanio\Desktop\newGraphs\2006 06\2006F15F.PAL", delim_whitespace=True, skiprows=13,names=headers)
data_2006F16F_06 = pd.read_csv(r"C:\Users\kanio\Desktop\newGraphs\2006 06\2006F16F.PAL", delim_whitespace=True, skiprows=13,names=headers)

# %%
# data_2006F10F_06 = data_2006F10F_06.apply(pd.to_numeric,errors = 'coerce').fillna(0)
# data_2006F11F_06 = data_2006F11F_06.apply(pd.to_numeric,errors = 'coerce').fillna(0)
# data_2006F12F_06 = data_2006F12F_06.apply(pd.to_numeric,errors = 'coerce').fillna(0)
# data_2006F13F_06 = data_2006F13F_06.apply(pd.to_numeric,errors = 'coerce').fillna(0)
# data_2006F14F_06 = data_2006F14F_06.apply(pd.to_numeric,errors = 'coerce').fillna(0)
# data_2006F15F_06 = data_2006F15F_06.apply(pd.to_numeric,errors = 'coerce').fillna(0)
# data_2006F16F_06 = data_2006F16F_06.apply(pd.to_numeric,errors = 'coerce').fillna(0)

# %%
# data_2006F14F_06

# %%
fig, ax = plt.subplots(3,1,figsize = (20,25))
ax[0].plot(data_2006F10F_06['LT'],data_2006F10F_06['foF2'],label ="2006F10F_06['foF2']" )
ax[0].plot(data_2006F11F_06['LT'],data_2006F11F_06['foF2'],label ="2006F11F_06['foF2']" )
ax[0].plot(data_2006F12F_06['LT'],data_2006F12F_06['foF2'],label ="2006F12F_06['foF2']" )
ax[0].plot(data_2006F13F_06['LT'],data_2006F13F_06['foF2'],label ="2006F13F_06['foF2']" )
ax[0].plot(data_2006F14F_06['LT'],data_2006F14F_06['foF2'],label ="2006F14F_06['foF2']" )
ax[0].plot(data_2006F15F_06['LT'],data_2006F15F_06['foF2'],label ="2006F15F_06['foF2']" )
ax[0].plot(data_2006F16F_06['LT'],data_2006F16F_06['foF2'],label ="2006F16F_06['foF2']" )

ax[0].legend(loc = 1)
# ax[0].tick_params(labelleft = False)

# ax[1].set_ylim([0,400])
# ax[1].set_yticklabels(np.arange(0,400,5),fontsize= 28)

ax[1].plot(data_2006F10F_06['LT'],data_2006F10F_06["h'F"],label ='2006F10F_06["h`F"]')
ax[1].plot(data_2006F11F_06['LT'],data_2006F11F_06["h'F"],label ='2006F11F_06["h`F"]')
ax[1].plot(data_2006F12F_06['LT'],data_2006F12F_06["h'F"],label ='2006F12F_06["h`F"]')
ax[1].plot(data_2006F13F_06['LT'],data_2006F13F_06["h'F"],label ='2006F13F_06["h`F"]')
ax[1].plot(data_2006F14F_06['LT'],data_2006F14F_06["h'F"],label ='2006F14F_06["h`F"]')
ax[1].plot(data_2006F15F_06['LT'],data_2006F15F_06["h'F"],label ='2006F15F_06["h`F"]')
ax[1].plot(data_2006F16F_06['LT'],data_2006F16F_06["h'F"],label ='2006F16F_06["h`F"]')


ax[1].legend(loc = 1)
# ax[1].tick_params(labelleft = False)

ax[2].plot(data_2006F10F_06['LT'],data_2006F10F_06['hpF2'])
ax[2].plot(data_2006F11F_06['LT'],data_2006F11F_06['hpF2'])
ax[2].plot(data_2006F12F_06['LT'],data_2006F12F_06['hpF2'])
ax[2].plot(data_2006F13F_06['LT'],data_2006F13F_06['hpF2'])
ax[2].plot(data_2006F14F_06['LT'],data_2006F14F_06['hpF2'])
ax[2].plot(data_2006F15F_06['LT'],data_2006F15F_06['hpF2'])
ax[2].plot(data_2006F16F_06['LT'],data_2006F16F_06['hpF2'])

# ax[2].tick_params(labelleft = False)

# %%
data_2006F10F_10 = pd.read_csv(r"C:\Users\kanio\Desktop\newGraphs\2006 10\2006F10F.PAL", delim_whitespace=True, skiprows=13,names=headers)
data_2006F11F_10 = pd.read_csv(r"C:\Users\kanio\Desktop\newGraphs\2006 10\2006F11F.PAL", delim_whitespace=True, skiprows=13,names=headers)
data_2006F12F_10 = pd.read_csv(r"C:\Users\kanio\Desktop\newGraphs\2006 10\2006F12F.PAL", delim_whitespace=True, skiprows=13,names=headers)
data_2006F13F_10 = pd.read_csv(r"C:\Users\kanio\Desktop\newGraphs\2006 10\2006F13F.PAL", delim_whitespace=True, skiprows=13,names=headers)
data_2006F14F_10 = pd.read_csv(r"C:\Users\kanio\Desktop\newGraphs\2006 10\2006F14F.PAL", delim_whitespace=True, skiprows=13,names=headers)
data_2006F15F_10 = pd.read_csv(r"C:\Users\kanio\Desktop\newGraphs\2006 10\2006F15F.PAL", delim_whitespace=True, skiprows=13,names=headers)
data_2006F16F_10 = pd.read_csv(r"C:\Users\kanio\Desktop\newGraphs\2006 10\2006F16F.PAL", delim_whitespace=True, skiprows=13,names=headers)

# %%
# data_2006F10F_10 = data_2006F10F_10.apply(pd.to_numeric,errors = 'coerce').fillna(0)
# data_2006F11F_10 = data_2006F11F_10.apply(pd.to_numeric,errors = 'coerce').fillna(0)
# data_2006F12F_10 = data_2006F12F_10.apply(pd.to_numeric,errors = 'coerce').fillna(0)
# data_2006F13F_10 = data_2006F13F_10.apply(pd.to_numeric,errors = 'coerce').fillna(0)
# data_2006F14F_10 = data_2006F14F_10.apply(pd.to_numeric,errors = 'coerce').fillna(0)
# data_2006F15F_10 = data_2006F15F_10.apply(pd.to_numeric,errors = 'coerce').fillna(0)
# data_2006F16F_10 = data_2006F16F_10.apply(pd.to_numeric,errors = 'coerce').fillna(0)

# %%
fig, ax = plt.subplots(3,1,figsize = (20,25))
ax[0].plot(data_2006F10F_10['LT'],data_2006F10F_10['foF2'],label ="2006F10F_10['foF2']" )
ax[0].plot(data_2006F11F_10['LT'],data_2006F11F_10['foF2'],label ="2006F11F_10['foF2']" )
ax[0].plot(data_2006F12F_10['LT'],data_2006F12F_10['foF2'],label ="2006F12F_10['foF2']" )
ax[0].plot(data_2006F13F_10['LT'],data_2006F13F_10['foF2'],label ="2006F13F_10['foF2']" )
ax[0].plot(data_2006F14F_10['LT'],data_2006F14F_10['foF2'],label ="2006F14F_10['foF2']" )
ax[0].plot(data_2006F15F_10['LT'],data_2006F15F_10['foF2'],label ="2006F15F_10['foF2']" )
ax[0].plot(data_2006F16F_10['LT'],data_2006F16F_10['foF2'],label ="2006F16F_10['foF2']" )

ax[0].legend(loc = 1)
# ax[0].tick_params(labelleft = False)

ax[1].plot(data_2006F10F_10['LT'],data_2006F10F_10["h'F"],label ='2006F10F_10["h`F"]')
ax[1].plot(data_2006F11F_10['LT'],data_2006F11F_10["h'F"],label ='2006F11F_10["h`F"]')
ax[1].plot(data_2006F12F_10['LT'],data_2006F12F_10["h'F"],label ='2006F12F_10["h`F"]')
ax[1].plot(data_2006F13F_10['LT'],data_2006F13F_10["h'F"],label ='2006F13F_10["h`F"]')
ax[1].plot(data_2006F14F_10['LT'],data_2006F14F_10["h'F"],label ='2006F14F_10["h`F"]')
ax[1].plot(data_2006F15F_10['LT'],data_2006F15F_10["h'F"],label ='2006F15F_10["h`F"]')
ax[1].plot(data_2006F16F_10['LT'],data_2006F16F_10["h'F"],label ='2006F16F_10["h`F"]')

ax[1].legend(loc = 1)
# ax[1].tick_params(labelleft = False)

ax[2].plot(data_2006F10F_10['LT'],data_2006F10F_10['hpF2'])
ax[2].plot(data_2006F11F_10['LT'],data_2006F11F_10['hpF2'])
ax[2].plot(data_2006F12F_10['LT'],data_2006F12F_10['hpF2'])
ax[2].plot(data_2006F13F_10['LT'],data_2006F13F_10['hpF2'])
ax[2].plot(data_2006F14F_10['LT'],data_2006F14F_10['hpF2'])
ax[2].plot(data_2006F15F_10['LT'],data_2006F15F_10['hpF2'])
ax[2].plot(data_2006F16F_10['LT'],data_2006F16F_10['hpF2'])

# ax[2].tick_params(labelleft = False)
